# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonwillschiu/scratch/blob/master/Copy_of_IOVOX_play_sound.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
# modify this URL to here the content
URL = 'https://api.iovox.com:444/Calls?v=3&method=getCallRecording&id=51592448120819'
HEADERS =  {
    'username':'IOVOXAPIUser',
    'secureKey':'3608707a7724bd8d5131bfe532f2c82e8d0973d4'
}
r=requests.get(URL, headers=HEADERS)
# r.content is an mp3/wav file
from IPython.display import Audio
Audio(r.content)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
