# %%
import requests
import os
import re

# %%
os.getcwd()
# Out:
# '/Users/jason.chiu/Dropbox/Home Pro/Meetup Script'

# %%
[x for x in os.listdir() if ('cookie' in x)]
# Out:
# ['meetup_cookies.pkl']

# %%
import pickle
COOKIES = pickle.load(open("meetup_cookies.pkl", "rb"))

# %%
COOKIES
# Out:
# [{'name': 'MEETUP_BROWSER_ID',
#   'value': '"id=6be65814-ea01-4aca-8977-5e85658ecff5"',
#   'path': '/',
#   'domain': '.meetup.com',
#   'secure': 'True',
#   'httpOnly': 'False',
#   'expiry': '2230292110',
#   'sameSite': 'None'},
#  {'name': 'SIFT_SESSION_ID',
#   'value': '0a3c7b2e-c5f4-461f-a256-0d8d061069d5',
#   'path': '/',
#   'domain': '.meetup.com',
#   'secure': 'True',
#   'httpOnly': 'False',
#   'expiry': '1599586510',
#   'sameSite': 'None'},
#  {'name': '_gcl_au',
#   'value': '1.1.1505995285.1599572112',
#   'path': '/',
#   'domain': '.meetup.com',
#   'secure': 'False',
#   'httpOnly': 'False',
#   'expiry': '1607348112',
#   'sameSite': 'None'},
#  {'name': 'MEETUP_AFFIL',
#   'value': 'affil=meetup&ref=/www.meetup.com',
#   'path': '/',
#   'domain': '.meetup.com',
#   'secure': 'True',
#   'httpOnly': 'True',
#   'expiry': '1603460113',
#   'sameSite': 'None'},
#  {'name': 'MUP_jqueryEn',
#   'value': 'on',
#   'path': '/',
#   'domain': '.meetup.com',
# ...

# %%
COOKIE_FROM_HAR = 'MEETUP_BROWSER_ID="id=9b908c62-fcec-4486-bcef-8895deb754d2"; fbm_2403839689=base_domain=.meetup.com; MEETUP_TRACK="id=22585e55-e90f-4959-ac8a-cd004d8c6400&l=1&s=935c94064359a68a06e91bc8d2a7a094b4aa08dc"; MEETUP_GA=gj%3Dsj7esmsa%252Csj7esmsa%252Csj7ea%26rv%3Dfe1msa%252Cfe1msa%252Cfe1a%26id%3Dnull; appbanner_accepted=dismissed=0; __stripe_mid=5210a753-741e-4142-bcae-6592af066bdeaf0b61; MEETUP_CSRF=ede03e43-740a-49dd-98a5-ba4d5733efb6; MUP_jqueryEn=on; memberId=230770839; gaEncryptedMemberId=9591bb16baeafa1ffbf018f5b5527f08; MEETUP_LANGUAGE=language=en&country=AU; MEETUP_SESSION=id=46dc3f91-7550-4ddc-a2e3-5145cdcda3dc; MEETUP_SEGMENT=member; MEETUP_MEMBER=id=230770839&status=1&timestamp=1599997157&bs=0&tz=Australia%2FSydney&zip=meetup1&country=au&city=Sydney&state=&lat=-33.87&lon=151.21&ql=false&s=a0c418f2e4e652270dc59d38091badeb23c911c0&scope=ALL&rem=1; SIFT_SESSION_ID=b38c8044-9d38-4f64-acd4-d0da98a94223; fbsr_2403839689=Jraaq2czZ8JZKIEt90qG0wuVQ93TGbOIZePHS3yESTk....; MEETUP_FB_DONE=1; __stripe_sid=81590f1e-0222-4cdb-bdcf-115b01f8123fa26415; x-mwp-csrf=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1dWlkIjoiMTQ3ODc2ZGUtNTg5NC00MWM5LWI2MzgtYjRhY2YzMGJmOTVlIiwidHlwZSI6ImNvb2tpZSIsImlhdCI6MTYwMDA4NzgyM30.jc6wBZg1DKWPFIRfflVNOi56CbtGA5-nV6vJDuCzor0; x-mwp-csrf-header=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1dWlkIjoiMTQ3ODc2ZGUtNTg5NC00MWM5LWI2MzgtYjRhY2YzMGJmOTVlIiwidHlwZSI6ImhlYWRlciIsImlhdCI6MTYwMDA4NzgyM30.is9h9KFQDnBl9lEATZ0ErrdKlQEaFpbfJfrehywGQWg'
COOKIE_FROM_HAR2 = 'MEETUP_BROWSER_ID="id=9b908c62-fcec-4486-bcef-8895deb754d2"; fbm_2403839689=base_domain=.meetup.com; MEETUP_TRACK="id=22585e55-e90f-4959-ac8a-cd004d8c6400&l=1&s=935c94064359a68a06e91bc8d2a7a094b4aa08dc"; MEETUP_GA=gj%3Dsj7esmsa%252Csj7esmsa%252Csj7ea%26rv%3Dfe1msa%252Cfe1msa%252Cfe1a%26id%3Dnull; MEETUP_CSRF=ede03e43-740a-49dd-98a5-ba4d5733efb6; MUP_jqueryEn=on; memberId=230770839; gaEncryptedMemberId=9591bb16baeafa1ffbf018f5b5527f08; MEETUP_LANGUAGE=language=en&country=AU; MEETUP_SESSION=id=46dc3f91-7550-4ddc-a2e3-5145cdcda3dc; MEETUP_SEGMENT=member; MEETUP_MEMBER=id=230770839&status=1&timestamp=1599997157&bs=0&tz=Australia%2FSydney&zip=meetup1&country=au&city=Sydney&state=&lat=-33.87&lon=151.21&ql=false&s=a0c418f2e4e652270dc59d38091badeb23c911c0&scope=ALL&rem=1; SIFT_SESSION_ID=b38c8044-9d38-4f64-acd4-d0da98a94223; fbsr_2403839689=Jraaq2czZ8JZKIEt90qG0wuVQ93TGbOIZePHS3yESTk....; MEETUP_FB_DONE=1; x-mwp-csrf=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1dWlkIjoiMjZiMzAxMmEtYjdiNS00MGIzLThlNzYtMWU1NzcwNTEzNDU5IiwidHlwZSI6ImNvb2tpZSIsImlhdCI6MTYwMDA4NzgxNn0.UTTddaUrfaHL84bo1anzyBmU63om-CkGuHxunU7Ag-Y; x-mwp-csrf-header=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1dWlkIjoiMjZiMzAxMmEtYjdiNS00MGIzLThlNzYtMWU1NzcwNTEzNDU5IiwidHlwZSI6ImhlYWRlciIsImlhdCI6MTYwMDA4NzgxNn0.89TObYstyvAaohwvzAXXEEYpgGWpFixqMwO7mQ8mhxo; click-track=%7B%22history%22%3A%5B%7B%22timestamp%22%3A%222020-09-14T08%3A50%3A23.916-04%3A00%22%2C%22lineage%22%3A%22%23attendButton%3Cdiv.flex-item.flex-item--shrink.eventCard--clickable%3Cdiv.flex.flex--row.flex--flexEnd.flex--alignCenter%3Cdiv.flex-item%3Cdiv.flex.flex--row.flex--spaceBetween.flex--alignCenter.padding--top.padding--bottom%3Cdiv.flex-item.flex-item--shrink%3Cdiv.flex.flex--column.flex--spaceBetween%3C%23eventCard-272860784%3Cdiv.chunk%3Cdiv.groupHome-eventsList-upcomingEvents.groupHome-eventsList-upcomingEventsOld%3Csection.section.atLarge_section--flush%3Cdiv.flex-item.flex-item--3.group-home-content%3Cdiv.flex.flex--column.atLarge_flex--row%3Cdiv.group-home%3Cdiv.bounds.bounds--wide%3Cdiv.groupPageWrapper--child%3C%23mupMain%3Cdiv.flex-item%3Cdiv.flex.flex--column.groupPageWrapper%3Cdiv.%3C%23root%22%2C%22linkText%22%3A%22Attend%22%2C%22coords%22%3A%5B-35%2C585%5D%2C%22tag%22%3A%22%22%7D%5D%7D'

# %%
def stringToCookie(string):
    out = {}
    for item in string.split('; '):
        i1 = re.search('^(.+?)=',item).group(1)
        i2 = re.search('=(.+)$',item).group(1)
        out[i1] = i2
    return out

# %%
COOKIEv2 = stringToCookie(COOKIE_FROM_HAR2)
COOKIEv2
# Out:
# {'MEETUP_BROWSER_ID': '"id=9b908c62-fcec-4486-bcef-8895deb754d2"',
#  'fbm_2403839689': 'base_domain=.meetup.com',
#  'MEETUP_TRACK': '"id=22585e55-e90f-4959-ac8a-cd004d8c6400&l=1&s=935c94064359a68a06e91bc8d2a7a094b4aa08dc"',
#  'MEETUP_GA': 'gj%3Dsj7esmsa%252Csj7esmsa%252Csj7ea%26rv%3Dfe1msa%252Cfe1msa%252Cfe1a%26id%3Dnull',
#  'MEETUP_CSRF': 'ede03e43-740a-49dd-98a5-ba4d5733efb6',
#  'MUP_jqueryEn': 'on',
#  'memberId': '230770839',
#  'gaEncryptedMemberId': '9591bb16baeafa1ffbf018f5b5527f08',
#  'MEETUP_LANGUAGE': 'language=en&country=AU',
#  'MEETUP_SESSION': 'id=46dc3f91-7550-4ddc-a2e3-5145cdcda3dc',
#  'MEETUP_SEGMENT': 'member',
#  'MEETUP_MEMBER': 'id=230770839&status=1&timestamp=1599997157&bs=0&tz=Australia%2FSydney&zip=meetup1&country=au&city=Sydney&state=&lat=-33.87&lon=151.21&ql=false&s=a0c418f2e4e652270dc59d38091badeb23c911c0&scope=ALL&rem=1',
#  'SIFT_SESSION_ID': 'b38c8044-9d38-4f64-acd4-d0da98a94223',
# ...

# %%
COOKIE2 = stringToCookie(COOKIE_FROM_HAR)
COOKIE2
# Out:
# {'MEETUP_BROWSER_ID': '"id=9b908c62-fcec-4486-bcef-8895deb754d2"',
#  'fbm_2403839689': 'base_domain=.meetup.com',
#  'MEETUP_TRACK': '"id=22585e55-e90f-4959-ac8a-cd004d8c6400&l=1&s=935c94064359a68a06e91bc8d2a7a094b4aa08dc"',
#  'MEETUP_GA': 'gj%3Dsj7esmsa%252Csj7esmsa%252Csj7ea%26rv%3Dfe1msa%252Cfe1msa%252Cfe1a%26id%3Dnull',
#  'appbanner_accepted': 'dismissed=0',
#  '__stripe_mid': '5210a753-741e-4142-bcae-6592af066bdeaf0b61',
#  'MEETUP_CSRF': 'ede03e43-740a-49dd-98a5-ba4d5733efb6',
#  'MUP_jqueryEn': 'on',
#  'memberId': '230770839',
#  'gaEncryptedMemberId': '9591bb16baeafa1ffbf018f5b5527f08',
#  'MEETUP_LANGUAGE': 'language=en&country=AU',
#  'MEETUP_SESSION': 'id=46dc3f91-7550-4ddc-a2e3-5145cdcda3dc',
#  'MEETUP_SEGMENT': 'member',
#  'MEETUP_MEMBER': 'id=230770839&status=1&timestamp=1599997157&bs=0&tz=Australia%2FSydney&zip=meetup1&country=au&city=Sydney&state=&lat=-33.87&lon=151.21&ql=false&s=a0c418f2e4e652270dc59d38091badeb23c911c0&scope=ALL&rem=1',
# ...

# %%
COOKIEv3 = requests.utils.cookiejar_from_dict(COOKIEv2)

# %%
COOKIE3 = requests.utils.cookiejar_from_dict(COOKIE2)
COOKIE3
# Out:
# <RequestsCookieJar[Cookie(version=0, name='MEETUP_BROWSER_ID', value='"id=9b908c62-fcec-4486-bcef-8895deb754d2"', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='MEETUP_CSRF', value='ede03e43-740a-49dd-98a5-ba4d5733efb6', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='MEETUP_FB_DONE', value='1', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='MEET
# ...

# %%
session = requests.Session()
session.cookies.update(COOKIEv3)

# %%
r = session.get("https://www.meetup.com/")
r
# Out:
# <Response [200]>

# %%
r1 = session.get(FISH_URL)
r1
# Out:
# <Response [200]>

# %%
def fix_cookies_and_load_to_requests(cookie_list, request_session):
    for index in range(len(cookie_list)):
        for item in cookie_list[index]:
            if type(cookie_list[index][item]) != str:
                print("Fix cookie value: ", cookie_list[index][item])
                cookie_list[index][item] = str(cookie_list[index][item])
        cookies = requests.utils.cookiejar_from_dict(cookie_list[index])
        request_session.cookies.update(cookies)
    return request_session

# %%
initial_state_with_cookies = fix_cookies_and_load_to_requests(cookie_list=COOKIES, request_session=session)
# Out:
# Fix cookie value:  True
# Fix cookie value:  False
# Fix cookie value:  2230292110
# Fix cookie value:  True
# Fix cookie value:  False
# Fix cookie value:  1599586510
# Fix cookie value:  False
# Fix cookie value:  False
# Fix cookie value:  1607348112
# Fix cookie value:  True
# Fix cookie value:  True
# Fix cookie value:  1603460113
# Fix cookie value:  True
# Fix cookie value:  False
# Fix cookie value:  False
# Fix cookie value:  False
# Fix cookie value:  1599572176
# Fix cookie value:  False
# Fix cookie value:  False
# Fix cookie value:  True
# Fix cookie value:  True
# Fix cookie value:  1615124171
# Fix cookie value:  True
# Fix cookie value:  False
# Fix cookie value:  1615124171
# Fix cookie value:  True
# Fix cookie value:  False
# Fix cookie value:  1615124171
# Fix cookie value:  True
# Fix cookie value:  True
# Fix cookie value:  True
# Fix cookie value:  True
# Fix cookie value:  2230292171
# Fix cookie value:  True
# Fix cookie value:  True
# ...

# %%
r = initial_state_with_cookies.get("https://www.meetup.com/")
r
# Out:
# <Response [200]>

# %%
FISH_URL = 'https://www.meetup.com/en-AU/Fishburners-Meetup/events/'

# %%
r1 = initial_state_with_cookies.get(FISH_URL)
r1
# Out:
# <Response [200]>

# %%
r1.cookies.get_dict()
# Out:
# {'x-mwp-csrf': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1dWlkIjoiNWI1YjkzMGYtMjM0MS00NmI5LTgyNzYtMGFlNDQ3ZjJkM2NmIiwidHlwZSI6ImNvb2tpZSIsImlhdCI6MTYwMDA5MzYwOX0.w9vDfYjeA_5wXAzhD9DmQ-VYJ5Y5K04NuNzGLoitPOQ',
#  'x-mwp-csrf-header': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1dWlkIjoiNWI1YjkzMGYtMjM0MS00NmI5LTgyNzYtMGFlNDQ3ZjJkM2NmIiwidHlwZSI6ImhlYWRlciIsImlhdCI6MTYwMDA5MzYwOX0.-2Ihei-y_MGCgyP87fAN2hSWUi2hj443BtyHVL40pKI'}

# %%
meets = re.findall('attendButton" href="(.+)"><span>Attend',r1.text)
meets
# Out:
# ['/en-AU/Fishburners-Meetup/events/272860784/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcmbxb/',
#  '/en-AU/Fishburners-Meetup/events/273129342/',
#  '/en-AU/Fishburners-Meetup/events/272860851/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcmbhc/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbdb/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbmb/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbvb/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbfc/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbnc/']

# %%
HEADERS = {
    'content-type':'application/x-www-form-urlencoded',
    'origin':'https://www.meetup.com',
    'referer':'https://www.meetup.com/en-AU/Fishburners-Meetup/events/272860784/?action=rsvp&response=yes'
}

# %%
# original from HAR file
#endpoint:Fishburners-Meetup/events/272860784/rsvps,meta:(method:post),params:(eventId:'272860784',fields:rsvp_counts,response:yes,urlname:Fishburners-Meetup),ref:rsvpAction_Fishburners-Meetup_272860784
DATA = {
    "endpoint":"Fishburners-Meetup/events/272860784/rsvps",
    "meta":"(method:post)",
    "params":"(eventId:'272860784'",
    "fields":"rsvp_counts",
    "response":"yes",
    "urlname":"Fishburners-Meetup)",
    "ref":"rsvpAction_Fishburners-Meetup_272860784"
}

# %%
POST_URL = 'https://www.meetup.com/mu_api/urlname/events/eventId'
REF_URL = 'https://www.meetup.com/en-AU/Fishburners-Meetup/events/272860784/?action=rsvp&response=yes'

# %%
r2a = session.get(url=REF_URL, cookies=COOKIEv3)
r2a
# Out:
# <Response [200]>

# %%
r2 = session.post(url=POST_URL, headers=HEADERS, data=DATA, cookies=COOKIEv3)
r2
# Out:
# <Response [500]>

# %%
r2.text
# Out:
# '{"statusCode":500,"error":"Internal Server Error","message":"An internal server error occurred"}'

# %%
r2.reason
# Out:
# 'Internal Server Error'

# %%
data1 = {
    endpoint:Fishburners-Meetup/events/272860784/rsvps,
    meta:(method:post),
    params:(eventId:'272860784',
    fields:rsvp_counts,
    response:yes,
    urlname:Fishburners-Meetup),
    ref:rsvpAction_Fishburners-Meetup_272860784
}
# Out:
#   File "<ipython-input-76-28e761a650d0>", line 3
#     meta:(method:post),
#                 ^
# SyntaxError: invalid syntax

# %%
session = requests.Session()

# %%
print(session.cookies.get_dict())
# Out:
# {'MEETUP_BROWSER_ID': '"id=9b34855f-391b-4055-a7a1-9768292e6ee4"', 'SIFT_SESSION_ID': '8f99363c-e526-436d-836b-f5a5ecec8840'}

# %%
BASE_URL = 'https://www.meetup.com'
ATTEND_SUFFIX = '?action=rsvp&response=yes'

# %%
fin = re.search(r'Log in',r.text)

# %%
fin.groups
# Out:
# <function Match.groups(default=None)>

# %%
r = initial_state_with_cookies.get("https://www.meetup.com/")

# %%
search_requests
# Out:
# <Response [200]>

# %%
print("search_requests:", search_requests)
# Out:
# search_requests: <Response [200]>

# %%
search_requests.text
# Out:
# '<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><link rel="preconnect" href="https://maps.googleapis.com"/><script async="" defer="" src="https://connect.facebook.net/en_US/sdk.js"></script><script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDmcqYY1xrGavCTuFAZ2e3uPQ1pHcbXeQw&amp;libraries=places"></script><style>.fresnel-container{margin:0;padding:0;}\n@media not all and (min-width:0px) and (max-width:575px){.fresnel-at-xs{display:none!important;}}\n@media not all and (min-width:576px) and (max-width:767px){.fresnel-at-sm{display:none!important;}}\n@media not all and (min-width:768px) and (max-width:991px){.fresnel-at-md{display:none!important;}}\n@media not all and (min-width:992px){.fresnel-at-lg{display:none!important;}}\n@media not all and (max-width:575px){.fresnel-lessThan-sm{display:none!important;}}\n
# ...

# %%
# Out:
# <Response [200]>

# %%
meets = re.findall('attendButton" href="(.+)"><span>Attend',t.text)
meets
# Out:
# ['/en-AU/Fishburners-Meetup/events/272860784/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcmbxb/',
#  '/en-AU/Fishburners-Meetup/events/273129342/',
#  '/en-AU/Fishburners-Meetup/events/272860851/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcmbhc/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbdb/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbmb/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbvb/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbfc/',
#  '/en-AU/Fishburners-Meetup/events/jzgdvrybcnbnc/']

# %%
BASE_URL + meets[0] + ATTEND_SUFFIX
# Out:
# 'https://www.meetup.com/en-AU/Fishburners-Meetup/events/272860784/?action=rsvp&response=yes'

# %%
session.get(BASE_URL + meets[0] + ATTEND_SUFFIX)
# Out:
# <Response [200]>

# %%
with open('fishburner.html','w') as f:
    f.write(t.text)

# %%
with open('meetuptest.html','w') as f:
    f.write(search_requests.text)

# %%
for cookie in COOKIES:
    COOKIES[cookie['name']] = cookie['value']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-bb33fe55c9f1> in <module>
#       1 for cookie in COOKIES:
# ----> 2     COOKIES[cookie['name']] = COOKIES['value']
#
# TypeError: list indices must be integers or slices, not str

# %%
COOKIES[14]
# Out:
# {'name': '_uetsid',
#  'value': '4491c3d4fe4d4a2121886f0a660712f7',
#  'path': '/',
#  'domain': '.meetup.com',
#  'secure': False,
#  'httpOnly': False,
#  'expiry': 1599658574,
#  'sameSite': 'None'}

# %%
# this looks promising as an example
# https://stackoverflow.com/questions/59532784/error-when-loading-cookies-into-a-python-request-session
from selenium import webdriver
import pickle
import requests

#Go to the website
driver = webdriver.Chrome(executable_path=r'C:\Path\\To\\Your\\chromedriver.exe')
driver.get('https://stackoverflow.com/')

#Save the cookies in a file
with open("C:\Path\To\Your\Filepath.pkl", 'wb') as f:
    pickle.dump(driver.get_cookies(), f)

driver.quit()
#you function to get the cookies from the file.
def load_cookies(filename):
  with open(filename, 'rb') as f:
    return pickle.load(f)

saved_cookies_list = load_cookies("C:\Path\To\Your\Filepath.pkl")

#Set request session
initial_state = requests.Session()
#Function to fix cookie values and add cookies to request_session
def fix_cookies_and_load_to_requests(cookie_list, request_session):
    for index in range(len(cookie_list)):
        for item in cookie_list[index]:
            if type(cookie_list[index][item]) != str:
                print("Fix cookie value: ", cookie_list[index][item])
                cookie_list[index][item] = str(cookie_list[index][item])
        cookies = requests.utils.cookiejar_from_dict(cookie_list[index])
        request_session.cookies.update(cookies)
    return request_session

initial_state_with_cookies = fix_cookies_and_load_to_requests(cookie_list=saved_cookies_list, request_session=initial_state)

search_requests = initial_state_with_cookies.get("https://stackoverflow.com/")
print("search_requests:", search_requests)
# Out:
# [{'name': 'MEETUP_BROWSER_ID', 'value': '"id=6be65814-ea01-4aca-8977-5e85658ecff5"', 'path': '/', 'domain': '.meetup.com', 'secure': True, 'httpOnly': False, 'expiry': 2230292110, 'sameSite': 'None'}, {'name': 'SIFT_SESSION_ID', 'value': '0a3c7b2e-c5f4-461f-a256-0d8d061069d5', 'path': '/', 'domain': '.meetup.com', 'secure': True, 'httpOnly': False, 'expiry': 1599586510, 'sameSite': 'None'}, {'name': '_gcl_au', 'value': '1.1.1505995285.1599572112', 'path': '/', 'domain': '.meetup.com', 'secure': False, 'httpOnly': False, 'expiry': 1607348112, 'sameSite': 'None'}, {'name': 'MEETUP_AFFIL', 'value': 'affil=meetup&ref=/www.meetup.com', 'path': '/', 'domain': '.meetup.com', 'secure': True, 'httpOnly': True, 'expiry': 1603460113, 'sameSite': 'None'}, {'name': 'MUP_jqueryEn', 'value': 'on', 'path': '/', 'domain': '.meetup.com', 'secure': True, 'httpOnly': False, 'sameSite': 'None'}, {'name': '_dc_gtm_UA-3226337-19', 'value': '1', 'path': '/', 'domain': '.meetup.com', 'secure': False, 'httpOn
# ...

# %%
r.text
# Out:
# '<!DOCTYPE html><html><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><link rel="preconnect" href="https://maps.googleapis.com"/><script async="" defer="" src="https://connect.facebook.net/en_US/sdk.js"></script><script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDmcqYY1xrGavCTuFAZ2e3uPQ1pHcbXeQw&amp;libraries=places"></script><style>.fresnel-container{margin:0;padding:0;}\n@media not all and (min-width:0px) and (max-width:575px){.fresnel-at-xs{display:none!important;}}\n@media not all and (min-width:576px) and (max-width:767px){.fresnel-at-sm{display:none!important;}}\n@media not all and (min-width:768px) and (max-width:991px){.fresnel-at-md{display:none!important;}}\n@media not all and (min-width:992px){.fresnel-at-lg{display:none!important;}}\n@media not all and (max-width:575px){.fresnel-lessThan-sm{display:none!important;}}\n
# ...

# %%
payload = {'user':'jasonsan@gmail.com', 'password':'4YtCGx%X&5yY'}
url = 'www.meetup.com'

with requests.Session() as s:
    r = s.post(url, data=payload)
    cookie = {'PHPSESSID': requests.utils.dict_from_cookiejar(s.cookies)['PHPSESSID']}

# %%
url = 'PROTECTED_URL'

session = requests.Session()

r = session.get(login)    # retrieve cookie, tokens, and other stuff

# parse the response to extract the tokens etc. (perhaps use BeautifulSoup). Store in "values". Add username and password to "values"

r = session.post(login, data=values)    # perform the login

r = session.get(url)                    # get the protected page

# %%
import pickle
import selenium.webdriver

# %%
driver = selenium.webdriver.Firefox()
driver.get('https://meetup.com')

# %%
with open('meetup_cookies.pkl','wb') as f:
    pickle.dump(driver.get_cookies(),f)

# %%
TOP_SHOT_EVENTS_URL = 'https://www.meetup.com/Topshot-Badminton-Meetup/events/'
TEST_URL   = 'https://www.meetup.com/en-AU/Fishburners-Meetup/events/'

# %%
driver = selenium.webdriver.Firefox()
# load the page without the cookie
driver.get('https://meetup.com')
# load the cookie
cookies = pickle.load(open("meetup_cookies.pkl", "rb"))
for cookie in cookies:
    driver.add_cookie(cookie)
# load the page again after the cookie is loaded, this is the same as logging in
driver.get('https://meetup.com')

# %%
driver.get(TEST_URL)

# %%
elem = driver.find_elements_by_partial_link_text("Attend")
print('found ', len(elem), ' events that can be RSVPd to')
# Out:
# found  13  events that can be RSVPd to

# %%
elem[:4][0].get_attribute('href')
# Out:
# 'https://www.meetup.com/en-AU/Fishburners-Meetup/events/272974021/?action=rsvp&response=yes'

# %%
# copy all attend links into an array
elems = []
for e in elem[:4]:
    elems.append(e.get_attribute('href'))

# %%
elems[0]
# Out:
# 'https://www.meetup.com/en-AU/Fishburners-Meetup/events/272974021/?action=rsvp&response=yes'

# %%
driver.get(elems[0])

# %%
driver.find_element_by_class_name('gtmEventFooter--attend-btn').click()
